# %%
import numpy as np
import random
import os
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
from torch import nn, optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
from torchvision import utils
from torchvision.models import list_models

# %% [markdown]
# # Transform Data

# %%
file_path = "C:\\Users\\erdem\\Downloads\\dogs-vs-cats\\train"

file_names = [f for f in os.listdir(file_path) if os.path.isfile(os.path.join(file_path, f))]

labels_encoded = [1 if i.split(".")[0] == "cat" else 0 for i in file_names]

# %%
for i in range(1,25000,5000):
    print(labels[i], labels_encoded[i])

# %%
# file_names = file_names[:5000]

img_tensors = []
transformed_imgs = []

# creating the transformation
img_transform = transforms.Compose([
    transforms.Resize((100, 100), antialias=True)
#     ,transforms.RandomResizedCrop(size=1000, antialias=True)
])

for i in tqdm(file_names):
    img = torch.tensor(plt.imread(f"{file_path}\\{i}")).permute(2, 0, 1)
    transformed_imgs.append(img_transform(img))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 25000/25000 [06:24<00:00, 65.07it/s]

# %%
transformed_imgs = torch.tensor(np.array(transformed_imgs))

# %%
plt.imshow(transformed_imgs[3].permute(1,2,0))

# %%
torch.save(transformed_imgs, "data.pt")
torch.save(torch.tensor(labels_encoded), "labels.pt")
